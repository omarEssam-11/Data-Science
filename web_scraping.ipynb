# %%
import requests
from bs4 import BeautifulSoup
import csv

# %%
date = input("Enter date in mm/dd/yyyy format: ").strip()
page = requests.get(f"https://www.yallakora.com/match-center/?date={date}")

#print(page.content) # return the page at a byte code format
# Out:
# Enter date in mm/dd/yyyy format: 10/13/2022
# b'\r\n<!DOCTYPE html>\r\n<html lang="ar">\r\n<head>\r\n    \r\n\r\n    <link rel="preload" href="https://www.yallakora.com//fonts/ykicons.woff2?ver=1" as="font" type="font/woff2" crossorigin />\r\n    <link rel="preload" href="https://www.yallakora.com//fonts/droidkufi-regular.woff2" as="font" type="font/woff2" crossorigin>\r\n    <link rel="preload" href="https://www.yallakora.com//fonts/droidkufi-bold.woff2" as="font" type="font/woff2" crossorigin>\r\n    <link rel="preload" href="https://www.yallakora.com//fonts/Stories/swiper-icons.woff2" as="font" type="font/woff2" crossorigin>\r\n\r\n\r\n    <!-- Preloading -->\r\n    <link rel="preload" as="style" href="/Content/StyleOnLoad.css?ver=0.1" crossorigin>\r\n\r\n    <!-- strat: Chartbeat-->\r\n    <script type="text/javascript">\r\n        var _sf_startpt = (new Date()).getTime()\r\n    </script>\r\n    <!-- end: chartbeat-->\r\n\r\n    <meta charset="utf-8" />\r\n    <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible">\r\n    <meta content="text/html; charset=UTF-8" http-equiv="content-type">\r\n    \r\n    <meta name="viewport" content="width=device-width, minimum-scale=1, initial-scale=1">\r\n    \r\n    \r\n\r\n\r\n    <!-- Download App Notification -->\r\n    \r\n\r\n    \r\n\r\n    <meta name="robots" content="max-snippet:-1, max-image-preview:large,max-video-preview:0">\r\n\r\n    <link href="https://www.yallakora.com//Images/Logo/favicon.ico?ver=1" rel="icon" type="image/ico" />\r\n    <link href="https://www.yallakora.com//Images/Logo/favicon.ico?ver=1" rel="shortcut icon" type="image/x-icon" />\r\n    <link href="https://www.yallakora.com//Images/Logo/192x192.png?ver=1" rel="icon" sizes="192x192" />\r\n    <link href="https://www.yallakora.com//Images/Logo/76x76.png?ver=1" rel="apple-touch-icon-precomposed" sizes="76x76" />\r\n    <link href="https://www.yallakora.com//Images/Logo/72x72.png?ver=1" rel="apple-touch-icon-precomposed" sizes="72x72" />\r\n    <link href="https://www.yallakora.com//Images/Logo/57x57.png?ver=1" rel="apple-touch-icon-precomposed" sizes="57x57" />\r\n    <link href="https://www.yallakora.com//Images/Logo/152x152.png?ver=1" rel="apple-touch-icon-precomposed" sizes="152x152" />\r\n    <link href="https://www.yallakora.com//Images/Logo/144x144.png?ver=1" rel="apple-touch-icon-precomposed" sizes="144x144" />\r\n    <link href="https://www.yallakora.com//Images/Logo/120x120.png?ver=1" rel="apple-touch-icon-precomposed" sizes="120x120" />\r\n    <link href="https://www.yallakora.com//Images/Logo/114x114.png?ver=1" rel="apple-touch-icon-precomposed" sizes="114x114" />\r\n\r\n    <title> \xd8\xac\xd8\xaf\xd9\x88\xd9\x84 \xd9\x85\xd8\xa8\xd8\xa7\xd8\xb1\xd9\x8a\xd8\xa7\xd8\xaa \xd8\xa7\xd9\x84\xd9\x8a\xd9\x88\xd9\x85 | \xd9\x8a\xd9\x84\xd8\xa7\xd9\x83\xd9\x88\xd8\xb1\xd8\xa9 </title>\r\n    <meta name="keywords" id="metaKeyword" content="\xd9\x85\xd9\x88\xd8\xa7\xd8\xb9\xd9\x8a\xd8\xaf \xd9\x85\xd8\xa8\xd8\xa7\xd8\xb1\xd9\x8a\xd8\xa7\xd8\xaa \xd8\xa7\xd9\x84\xd9\x8a\xd9\x88\xd9\x85 \xd9\x88 \xd8\xa7\xd9\x84\xd9\x82\xd9\x86\xd9\x88\xd8\xa7\xd8\xaa \xd8\xa7\xd9\x84\xd9\x86\xd8\xa7\xd9\x82\xd9\x84\xd8\xa9 \xd9\x84\xd9\x87\xd8\xa7 \xd9\x84\xd8\xac\xd9\x85\xd9\x8a\xd8\xb9 \xd8\xa7\xd9\x84\xd8\xaf\xd9\x88\xd8\xb1\xd9\x8a\xd8\xa7\xd8\xaa \xd8\xa7\xd9\x84\xd9\x85\xd8\xad\xd9\x84\xd9\x8a\xd8\xa9 \xd9\x88 \xd8\xa7\xd9\x84\xd8\xb9\xd8\xb1\xd8\xa8\xd9\x8a\xd8\xa9 \xd9\x88 \xd8\xa7\xd9\x84\xd8\xa7\xd9\x88\xd8\xb1\xd9\x88\xd8\xa8\xd9\x8a\xd8\xa9" />\r\n    <meta name="description" id="metaDesc" content="\xd9\x85\xd9\x88\xd8\xa7\xd8\xb9\xd9\x8a\xd8\xaf \xd9\x85\xd8\xa8\xd8\xa7\xd8\xb1\xd9\x8a\xd8\xa7\xd8\xaa \xd8\xa7\xd9\x84\xd9\x8a\xd9\x88\xd9\x85 \xd9\x88 \xd8\xa7\xd9\x84\xd9\x82\xd9\x86\xd9\x88\xd8\xa7\xd8\xaa \xd8\xa7\xd9\x84\xd9\x86\xd8\xa7\xd9\x82\xd9\x84\xd8\xa9 \xd9\x84\xd9\x87\xd8\xa7 \xd9\x84\xd8\xac\xd9\x85\xd9\x8a\xd8\xb9 \xd8\xa7\xd9\x84\xd8\xaf\xd9\x88\xd8\xb1\xd9\x8a\xd8\xa7\xd8\xaa \xd8\xa7\xd9\x84\xd9\x85\xd8\xad\xd9\x84\xd9\x8a\xd8\xa9  ...

# %%
# parsing transform the byte code to readable format

src = page.content
soup = BeautifulSoup(src, 'lxml')
# print(soup)

# %%
matcheslist = []
championship = soup.find_all('div', {'class' :'matchCard'})
#print(championship[0].find('h2').text.strip())
# Out:
# الدوري الأوروبي

# %%
all_matches_data = championship[0].find_all('div', {'class': 'teamsData'})
# print(all_matches_data)
# Out:
# [<div class="teamsData">
# <!-- Team A -->
# <div class="teams teamA">
# <img alt="كاراباج اجدام" data-src="https://media.gemini.media/img/yallakora/IOSTeams//120/\2018\8\12\QarabagFK2018_8_12_13_6.jpg" height="24" loading="lazy" onerror="this.onerror=null;this.src='https://media.gemini.media/img/yallakora/IOSTeams/YK-Generic-team-logo.png'" src="https://media.gemini.media/img/yallakora/IOSTeams//120/\2018\8\12\QarabagFK2018_8_12_13_6.jpg" width="24"/>
# <p>كاراباج اجدام</p>
# </div>
# <!-- Match Result -->
# <div class="MResult">
# <span class="score">0</span>
# <span>-</span>
# <span class="score">0</span>
# <span class="time">18:45</span>
# </div>
# <!-- Team B -->
# <div class="teams teamB">
# <img alt="أوليمبياكوس" data-src="https://media.gemini.media/img/yallakora/IOSTeams//120/\2018\9\13\Olympiacos2018_9_13_12_40.jpg" height="24" loading="lazy" onerror="this.onerror=null;this.src='https://media.gemini.media/img/yallakora/IOSTeams/YK-Generic-team-logo.png'" src="https://media.gemini.media/img/yallakora/IOSTeams//120/\2018\9\13\Olympiacos2018_9_13_12_40.jpg" width="24"/>
# <p>أوليمبياكوس</p>
# </div>
# </div>, <div class="teamsData">
# <!-- Team A -->
# <div class="teams teamA">
# <img alt="سان جيلواز" data-src="https://media.gemini.media/img/yallakora/IOSTeams//120/\2022\9\1\Saint-Gilloise12022_9_1_17_50.jpg" height="24" loading="lazy" onerror="this.onerror=null;this.src='https://media.gemini.media/img/yallakora/IOSTeams/YK-Generic-team-logo.png'" src="https://media.gemini.media/img/yallakora/IOSTeams//120/\2022\9\1\Saint-Gilloise12022_9_1_17_50.jpg" width="24"/>
# <p>سان جيلواز</p>
# </div>
# <!-- Match Result -->
# <div class="MResult">
# <span class="score">3</span>
# <span>-</span>
# <span class="score">3</span>
# <span class="time">18:45</span>
# </div>
# <!-- Team B -->
# <div class="teams teamB">
# <img alt="سبورتينج براجا" data-src="https://media.gemini.media/img/yallakora/IOSTeams//120/\2018\7\30\SportingBraga2018_7_30_10_23.jpg" height="24" loading="lazy" onerror="this.onerror=null;this.src='https://media.gemini.media/img/yallakora/IOSTeams/YK-Generic-team-logo.png'" src="https://media.gemini.media/img/yallakora/IOSTeams//120/\2018\7\30\SportingBraga2018_7_30_10_23.jpg" width="24"/>
# <p>سبورتينج براجا</p>
# </div>
# </div>, <div class="teamsData">
# <!-- Team A -->
# <div class="teams teamA">
# <img alt="آيك لارانكا" data-src="https://media.gemini.media/img/yallakora/IOSTeams//120/\2018\9\13\AEKLarnaca2018_9_13_12_36.jpg" height="24" loading="lazy" onerror="this.onerror=null;this.src='https://media.gemini.media/img/yallakora/IOSTeams/YK-Generic-team-logo.png'" src="https://media.gemini.media/img/yallakora/IOSTeams//120/\2018\9\13\AEKLarnaca2018_9_13_12_36.jpg" width="24"/>
# <p>آيك لارانكا</p>
# </div>
# <!-- Match Result -->
# <div class="MResult">
# <span class="score">1</span>
# <span>-</span>
# <span class="score">2</span>
# <span class="time">18:45</span>
# </div>
# <!-- Team B -->
# <div class="teams teamB">
# <img alt="فنربخشة" data-src="https://media.gemini.media/img/yallakora/IOSTeams//120/\2018\8\12\Fenerbahce2018_8_12_13_1.jpg" height="24" loading="lazy" onerror="this.onerror=null;this.src='https://media.gemini.media/img/yallakora/IOSTeams/YK-Generic-team-logo.png'" src="https://media.gemini.media/img/yallakora/IOSTeams//120/\2018\8\12\Fenerbahce2018_8_12_13_1.jpg" width="24"/>
# <p>فنربخشة</p>
# </div>
# </div>, <div class="teamsData">
# <!-- Team A -->
# <div class="teams teamA">
# <img alt="ريال بيتيس" data-src="https://media.gemini.media/img/yallakora/IOSTeams//120/\2018\7\29\RealBetis2018_7_29_14_50.jpg" height="24" loading="lazy" onerror="this.onerror=null;this.src='https://media.gemini.media/img/yallakora/IOSTeams/YK-Generic-team-logo.png'" src="https://media.gemini.media/img/yallakora/IOSTeams//120/\2018\7\29\RealBetis2018_7_29_14_50.jpg" width="24"/>
# <p>ريال بيتيس</p>
# </div>
# <!-- Match Result -->
# <div class="MResult">
# <span class="score">1</span>
# <span>-</span>
# <span class="score">1</span>
# <span class="time">18:45</span>
# </div>
# <!-- Team B -->
# <div class="teams teamB">
# <img alt="روما" data-src="https://media.gemini.media/img/yallakora/IOSTeams//120/\2018\7\29\ASRoma2018_7_29_15_7.jpg" height="24" loading="lazy" onerror="this.onerror=null;this.src='https://media.gemini.media/img/yallakora/IOSTeams/YK-Generic-team-logo.png'" src="https://media.gemini.media/img/yallakora/IOSTeams//120/\2018\7\29\ASRoma2018_7_29_15_7.jpg" width="24"/>
# <p>روما</p>
# </div>
# </div>, <div class="teamsData">
# <!-- Team A -->
# <div class="teams teamA">
# <img alt="جليمت " data-src="https://media.gemini.media/img/yallakora/IOSTeams//120/\2021\9\8\32021_9_8_20_53.jpg" height="24" loading="lazy" onerror="this.onerror=null;this.src='https://media.gemini.media/img/yallakora/IOSTeams/YK-Generic-team-logo.png'" src="https://media.gemini.media/img/yallakora/IOSTeams//120/\2021\9\8\32021_9_8_20_53.jpg" width="24"/>
# <p>جليمت </p>
# </div>
# <!-- Match Result -->
# <div class="MResult">
# <span class="score">0</span>
# <span>-</span>
# <span class="score">1</span>
# <span class="time">18:45</span>
# </div>
# <!-- Team B -->
# <div class="teams teamB">
# <img alt="أرسنال" data-src="https://media.gemini.media/img/yallakora/IOSTeams//120/\2021\9\5\Arsenal2021_9_5_14_15.jpg" height="24" loading="lazy" onerror="this.onerror=null;this.src='https://media.gemini.media/img/yallakora/IOSTeams/YK-Generic-team-logo.png'" src="https://media.gemini.media/img/yallakora/IOSTeams//120/\2021\9\5\Arsenal2021_9_5_14_15.jpg" width="24"/>
# <p>أرسنال</p>
# </div>
# </div>, <div class="teamsData">
# <!-- Team A -->
# <div class="teams teamA">
# <img alt="دينامو كييف" data-src="https://media.gemini.media/img/yallakora/IOSTeams//120/\2018\8\12\DynamoKyiv2018_8_12_13_1.jpg" height="24" loading="lazy" onerror="this.onerror=null;this.src='https://media.gemini.media/img/yallakora/IOSTeams/YK-Generic-team-logo.png'" src="https://media.gemini.media/img/yallakora/IOSTeams//120/\2018\8\12\DynamoKyiv2018_8_12_13_1.jpg" width="24"/>
# <p>دينامو كييف</p>
# </div>
# <!-- Match Result -->
# <div class="MResult">
# <span class="score">0</span>
# <span>-</span>
# <span class="score">1</span>
# <span class="time">18:45</span>
# </div>
# <!-- Team B -->
# <div class="teams teamB">
# <img alt="رين" data-src="https://media.gemini.media/img/yallakora/IOSTeams//120/\2018\7\29\Rennais2018_7_29_17_14.jpg" height="24" loading="lazy" onerror="this.onerror=null;this.src='https://media.gemini.media/img/yallakora/IOSTeams/YK-Generic-team-logo.png'" src="https://media.gemini.media/img/yallakora/IOSTeams//120/\2018\7\29\Rennais2018_7_29_17_14.jpg" width="24"/>
# <p>رين</p>
# </div>
# </div>, <div class="teamsData">
# <!-- Team A -->
# <div class="teams teamA">
# <img alt="فينورد" data-src="https://media.gemini.media/img/yallakora/IOSTeams//120/\2021\7\15\Feyenoord2021_7_15_9_27.jpg" height="24" loading="lazy" onerror="this.onerror=null;this.src='https://media.gemini.media/img/yallakora/IOSTeams/YK-Generic-team-logo.png'" src="https://media.gemini.media/img/yallakora/IOSTeams//120/\2021\7\15\Feyenoord2021_7_15_9_27.jpg" width="24"/>
# <p>فينورد</p>
# </div>
# <!-- Match Result -->
# <div class="MResult">
# <span class="score">2</span>
# <span>-</span>
# <span class="score">2</span>
# <span class="time">18:45</span>
# </div>
# <!-- Team B -->
# <div class="teams teamB">
# <img alt="ميتييلاند " data-src="https://media.gemini.media/img/yallakora/IOSTeams//120/\2015\9\7\Midtjylland12015_9_7_13_47.jpg" height="24" loading="lazy" onerror="this.onerror=null;this.src='https://media.gemini.media/img/yallakora/IOSTeams/YK-Generic-team-logo.png'" src="https://media.gemini.media/img/yallakora/IOSTeams//120/\2015\9\7\Midtjylland12015_9_7_13_47.jpg" width="24"/>
# <p>ميتييلاند </p>
# </div>
# </div>, <div class="teamsData">
# <!-- Team A -->
# <div class="teams teamA">
# <img alt="نانت" data-src="https://media.gemini.media/img/yallakora/IOSTeams//120/\2021\9\5\Nantes2021_9_5_14_49.jpg" height="24" loading="lazy" onerror="this.onerror=null;this.src='https://media.gemini.media/img/yallakora/IOSTeams/YK-Generic-team-logo.png'" src="https://media.gemini.media/img/yallakora/IOSTeams//120/\2021\9\5\Nantes2021_9_5_14_49.jpg" width="24"/>
# <p>نانت</p>
# </div>
# <!-- Match Result -->
# <div class="MResult">
# <span class="score">0</span>
# <span>-</span>
# <span class="score">4</span>
# <span class="time">18:45</span>
# </div>
# <!-- Team B -->
# <div class="teams teamB">
# <img alt="فرايبورج" data-src="https://media.gemini.media/img/yallakora/IOSTeams//120/\2018\7\29\Freiburg2018_7_29_16_7.jpg" height="24" loading="lazy" onerror="this.onerror=null;this.src='https://media.gemini.media/img/yallakora/IOSTeams/YK-Generic-team-logo.png'" src="https://media.gemini.media/img/yallakora/IOSTeams//120/\2018\7\29\Freiburg2018_7_29_16_7.jpg" width="24"/>
# <p>فرايبورج</p>
# </div>
# </div>, <div class="teamsData">
# <!-- Team A -->
# <div class="teams teamA">
# <img alt="فيرينكفاروسي" data-src="https://media.gemini.media/img/yallakora/IOSTeams//120/\2021\7\14\FerencvarosiTC2021_7_14_17_33.jpg" height="24" loading="lazy" onerror="this.onerror=null;this.src='https://media.gemini.media/img/yallakora/IOSTeams/YK-Generic-team-logo.png'" src="https://media.gemini.media/img/yallakora/IOSTeams//120/\2021\7\14\FerencvarosiTC2021_7_14_17_33.jpg" width="24"/>
# <p>فيرينكفاروسي</p>
# </div>
# <!-- Match Result -->
# <div class="MResult">
# <span class="score">2</span>
# <span>-</span>
# <span class="score">1</span>
# <span class="time">21:00</span>
# </div>
# <!-- Team B -->
# <div class="teams teamB">
# <img alt="سرفينا زافيزدا" data-src="https://media.gemini.media/img/yallakora/IOSTeams//120/\2018\8\12\RedStar2018_8_12_13_7.jpg" height="24" loading="lazy" onerror="this.onerror=null;this.src='https://media.gemini.media/img/yallakora/IOSTeams/YK-Generic-team-logo.png'" src="https://media.gemini.media/img/yallakora/IOSTeams//120/\2018\8\12\RedStar2018_8_12_13_7.jpg" width="24"/>
# <p>سرفينا زافيزدا</p>
# </div>
# </div>, <div class="teamsData">
# <!-- Team A -->
# <div class="teams teamA">
# <img alt="لاتسيو" data-src="https://media.gemini.media/img/yallakora/IOSTeams//120/\2018\7\29\Lazio2018_7_29_15_9.jpg" height="24" loading="lazy" onerror="this.onerror=null;this.src='https://media.gemini.media/img/yallakora/IOSTeams/YK-Generic-team-logo.png'" src="https://media.gemini.media/img/yallakora/IOSTeams//120/\2018\7\29\Lazio2018_7_29_15_9.jpg" width="24"/>
# <p>لاتسيو</p>
# </div>
# <!-- Match Result -->
# <div class="MResult">
# <span class="score">2</span>
# <span>-</span>
# <span class="score">2</span>
# <span class="time">21:00</span>
# </div>
# <!-- Team B -->
# <div class="teams teamB">
# <img alt="شتورم جراتس" data-src="https://media.gemini.media/img/yallakora/IOSTeams//120/\2021\9\19\SturmGraz2021_9_19_9_24.jpg" height="24" loading="lazy" onerror="this.onerror=null;this.src='https://media.gemini.media/img/yallakora/IOSTeams/YK-Generic-team-logo.png'" src="https://media.gemini.media/img/yallakora/IOSTeams//120/\2021\9\19\SturmGraz2021_9_19_9_24.jpg" width="24"/>
# <p>شتورم جراتس</p>
# </div>
# </div>, <div class="teamsData">
# <!-- Team A -->
# <div class="teams teamA">
# <img alt="لودوجوريتس " data-src="https://media.gemini.media/img/yallakora/IOSTeams//120/\2018\9\13\Ludogorets2018_9_13_12_35.jpg" height="24" loading="lazy" onerror="this.onerror=null;this.src='https://media.gemini.media/img/yallakora/IOSTeams/YK-Generic-team-logo.png'" src="https://media.gemini.media/img/yallakora/IOSTeams//120/\2018\9\13\Ludogorets2018_9_13_12_35.jpg" width="24"/>
# <p>لودوجوريتس </p>
# </div>
# <!-- Match Result -->
# <div class="MResult">
# <span class="score">2</span>
# <span>-</span>
# <span class="score">0</span>
# <span class="time">21:00</span>
# </div>
# <!-- Team B -->
# <div class="teams teamB">
# <img alt="هلسنكي" data-src="https://media.gemini.media/img/yallakora/IOSTeams//120/\2021\9\19\HJK2021_9_19_9_45.jpg" height="24" loading="lazy" onerror="this.onerror=null;this.src='https://media.gemini.media/img/yallakora/IOSTeams/YK-Generic-team-logo.png'" src="https://media.gemini.media/img/yallakora/IOSTeams//120/\2021\9\19\HJK2021_9_19_9_45.jpg" width="24"/>
# <p>هلسنكي</p>
# </div>
# </div>, <div class="teamsData">
# <!-- Team A -->
# <div class="teams teamA">
# <img alt="مانشستر يونايتد" data-src="https://media.gemini.media/img/yallakora/IOSTeams//120/\2018\7\29\ManchesterUnited2018_7_29_15_29.jpg" height="24" loading="lazy" onerror="this.onerror=null;this.src='https://media.gemini.media/img/yallakora/IOSTeams/YK-Generic-team-logo.png'" src="https://media.gemini.media/img/yallakora/IOSTeams//120/\2018\7\29\ManchesterUnited2018_7_29_15_29.jpg" width="24"/>
# <p>مانشستر يونايتد</p>
# </div>
# <!-- Match Result -->
# <div class="MResult">
# <span class="score">1</span>
# <span>-</span>
# <span class="score">0</span>
# <span class="time">21:00</span>
# </div>
# <!-- Team B -->
# <div class="teams teamB">
# <img alt="أومونيا" data-src="https://media.gemini.media/img/yallakora/IOSTeams//120/\2021\7\15\OmonoiaFC2021_7_15_9_49.jpg" height="24" loading="lazy" onerror="this.onerror=null;this.src='https://media.gemini.media/img/yallakora/IOSTeams/YK-Generic-team-logo.png'" src="https://media.gemini.media/img/yallakora/IOSTeams//120/\2021\7\15\OmonoiaFC2021_7_15_9_49.jpg" width="24"/>
# <p>أومونيا</p>
# </div>
# </div>, <div class="teamsData">
# <!-- Team A -->
# <div class="teams teamA">
# <img alt="إيندهوفن" data-src="https://media.gemini.media/img/yallakora/IOSTeams//120/\2018\9\10\PSVEindhoven2018_9_10_12_41.jpg" height="24" loading="lazy" onerror="this.onerror=null;this.src='https://media.gemini.media/img/yallakora/IOSTeams/YK-Generic-team-logo.png'" src="https://media.gemini.media/img/yallakora/IOSTeams//120/\2018\9\10\PSVEindhoven2018_9_10_12_41.jpg" width="24"/>
# <p>إيندهوفن</p>
# </div>
# <!-- Match Result -->
# <div class="MResult">
# <span class="score">5</span>
# <span>-</span>
# <span class="score">0</span>
# <span class="time">21:00</span>
# </div>
# <!-- Team B -->
# <div class="teams teamB">
# <img alt="زيورخ" data-src="https://media.gemini.media/img/yallakora/IOSTeams//120/\2018\9\13\Zurich2018_9_13_12_34.jpg" height="24" loading="lazy" onerror="this.onerror=null;this.src='https://media.gemini.media/img/yallakora/IOSTeams/YK-Generic-team-logo.png'" src="https://media.gemini.media/img/yallakora/IOSTeams//120/\2018\9\13\Zurich2018_9_13_12_34.jpg" width="24"/>
# <p>زيورخ</p>
# </div>
# </div>, <div class="teamsData">
# <!-- Team A -->
# <div class="teams teamA">
# <img alt="ريال سوسيداد" data-src="https://media.gemini.media/img/yallakora/IOSTeams//120/\2018\7\29\RealSociedad2018_7_29_14_56.jpg" height="24" loading="lazy" onerror="this.onerror=null;this.src='https://media.gemini.media/img/yallakora/IOSTeams/YK-Generic-team-logo.png'" src="https://media.gemini.media/img/yallakora/IOSTeams//120/\2018\7\29\RealSociedad2018_7_29_14_56.jpg" width="24"/>
# <p>ريال سوسيداد</p>
# </div>
# <!-- Match Result -->
# <div class="MResult">
# <span class="score">3</span>
# <span>-</span>
# <span class="score">0</span>
# <span class="time">21:00</span>
# </div>
# <!-- Team B -->
# <div class="teams teamB">
# <img alt="شيريف تيراسبول" data-src="https://media.gemini.media/img/yallakora/IOSTeams//120/\2021\9\14\SheriffTiraspol2021_9_14_10_46.jpg" height="24" loading="lazy" onerror="this.onerror=null;this.src='https://media.gemini.media/img/yallakora/IOSTeams/YK-Generic-team-logo.png'" src="https://media.gemini.media/img/yallakora/IOSTeams//120/\2021\9\14\SheriffTiraspol2021_9_14_10_46.jpg" width="24"/>
# <p>شيريف تيراسبول</p>
# </div>
# </div>, <div class="teamsData">
# <!-- Team A -->
# <div class="teams teamA">
# <img alt="طرابزون سبور" data-src="https://media.gemini.media/img/yallakora/IOSTeams//120/\2021\7\15\Trabzonspor2021_7_15_15_32.jpg" height="24" loading="lazy" onerror="this.onerror=null;this.src='https://media.gemini.media/img/yallakora/IOSTeams/YK-Generic-team-logo.png'" src="https://media.gemini.media/img/yallakora/IOSTeams//120/\2021\7\15\Trabzonspor2021_7_15_15_32.jpg" width="24"/>
# <p>طرابزون سبور</p>
# </div>
# <!-- Match Result -->
# <div class="MResult">
# <span class="score">4</span>
# <span>-</span>
# <span class="score">0</span>
# <span class="time">21:00</span>
# </div>
# <!-- Team B -->
# <div class="teams teamB">
# <img alt="موناكو" data-src="https://media.gemini.media/img/yallakora/IOSTeams//120/\2018\7\29\Monaco2018_7_29_17_13.jpg" height="24" loading="lazy" onerror="this.onerror=null;this.src='https://media.gemini.media/img/yallakora/IOSTeams/YK-Generic-team-logo.png'" src="https://media.gemini.media/img/yallakora/IOSTeams//120/\2018\7\29\Monaco2018_7_29_17_13.jpg" width="24"/>
# <p>موناكو</p>
# </div>
# </div>, <div class="teamsData">
# <!-- Team A -->
# <div class="teams teamA">
# <img alt="يونيون برلين" data-src="https://media.gemini.media/img/yallakora/IOSTeams//120/\2018\9\12\UnionBerlin2018_9_12_13_37.jpg" height="24" loading="lazy" onerror="this.onerror=null;this.src='https://media.gemini.media/img/yallakora/IOSTeams/YK-Generic-team-logo.png'" src="https://media.gemini.media/img/yallakora/IOSTeams//120/\2018\9\12\UnionBerlin2018_9_12_13_37.jpg" width="24"/>
# <p>يونيون برلين</p>
# </div>
# <!-- Match Result -->
# <div class="MResult">
# <span class="score">1</span>
# <span>-</span>
# <span class="score">0</span>
# <span class="time">21:00</span>
# </div>
# <!-- Team B -->
# <div class="teams teamB">
# <img alt="مالمو" data-src="https://media.gemini.media/img/yallakora/IOSTeams//120/\2018\8\12\Malmo2018_8_12_13_5.jpg" height="24" loading="lazy" onerror="this.onerror=null;this.src='https://media.gemini.media/img/yallakora/IOSTeams/YK-Generic-team-logo.png'" src="https://media.gemini.media/img/yallakora/IOSTeams//120/\2018\8\12\Malmo2018_8_12_13_5.jpg" width="24"/>
# <p>مالمو</p>
# </div>
# </div>]

# %%
# titles of championships
all_titles = []
for i in championship:
    all_titles.append(i.find('h2').text.strip())
print(all_titles)
# Out:
# ['الدوري الأوروبي', 'دوري المؤتمر الأوروبي']

# %%
# all_matches = {}
# for i in championship:
#   for j in i.find_all('div', {'class': 'teamsData'}):
#     all_matches[i.find('h2').text.strip()]['teamsA'].append(j.find('div', {'class': 'teams teamA'}.text.strip()))
#     all_matches[i.find('h2').text.strip()]['teamsB'].append(j.find('div', {'class': 'teams teamB'}.text.strip()))
#     all_matches[i.find('h2').text.strip()]['result'].append(j.find('div', {'class': 'MResult'}.text.strip()))

# print(all_matches)



all_matches = {}
for i in championship:
    title = i.find('h2').text.strip()  # Get the title for this championship
    if title not in all_matches:  # Check if the title exists in the dictionary
        all_matches[title] = {'teamsA': [], 'teamsB': [], 'result': [], 'time': []}  # Initialize it if it doesn't

    for j in i.find_all('div', {'class': 'teamsData'}):
        all_matches[title]['teamsA'].append(j.find('div', {'class': 'teams teamA'}).text.strip())
        all_matches[title]['teamsB'].append(j.find('div', {'class': 'teams teamB'}).text.strip())
        all_results = j.find('div', {'class': 'MResult'}).find_all('span', {'class': 'score'})
        result = (all_results[0].text.strip()) + "-" + all_results[1].text.strip()
        all_matches[title]['result'].append(result)
        all_matches[title]['time'].append(j.find('div', {'class': 'MResult'}).find('span', {'class': 'time'}).text.strip())

print(all_matches)
# Out:
# {'الدوري الأوروبي': {'teamsA': ['كاراباج اجدام', 'سان جيلواز', 'آيك لارانكا', 'ريال بيتيس', 'جليمت', 'دينامو كييف', 'فينورد', 'نانت', 'فيرينكفاروسي', 'لاتسيو', 'لودوجوريتس', 'مانشستر يونايتد', 'إيندهوفن', 'ريال سوسيداد', 'طرابزون سبور', 'يونيون برلين'], 'teamsB': ['أوليمبياكوس', 'سبورتينج براجا', 'فنربخشة', 'روما', 'أرسنال', 'رين', 'ميتييلاند', 'فرايبورج', 'سرفينا زافيزدا', 'شتورم جراتس', 'هلسنكي', 'أومونيا', 'زيورخ', 'شيريف تيراسبول', 'موناكو', 'مالمو'], 'result': ['0-0', '3-3', '1-2', '1-1', '0-1', '0-1', '2-2', '0-4', '2-1', '2-2', '2-0', '1-0', '5-0', '3-0', '4-0', '1-0'], 'time': ['18:45', '18:45', '18:45', '18:45', '18:45', '18:45', '18:45', '18:45', '21:00', '21:00', '21:00', '21:00', '21:00', '21:00', '21:00', '21:00']}, 'دوري المؤتمر الأوروبي': {'teamsA': ['إسطنبول باشاكشهير', 'فيورنتينا', 'أوستريا فيينا', 'بارتيزان', 'ابولون ليماسول', 'يورجوردينس', 'كلوج', 'سلوفان براتيسلافا', 'ستيوا بوخارست', 'وست هام يونايتد', 'هابويل بئر سبع', 'نيس', 'فادوز', 'شامروك روفرز', 'بالكاني', 'زالجيريس فيلنوس'], 'teamsB': ['نادي آر إف إس', 'هارت أوف ميدلوثيان', 'فياريال', 'كولن', 'الكمار', 'جينت', 'سلافيا براج', 'بازل', 'سيلكيبورج', 'أندرلخت', 'ليخ بوزنان', 'سلوفاكو', 'دنيبرو-1', 'مولده', 'سيفاسبور', 'بيونيك'], 'result': ['3-0', '5-1', '0-1', '2-0', '1-0', '4-2', '2-0', '3-3', '0-5', '2-1', '1-1', '1-2', '1-2', '0-2', '1-2', '2-1'], 'time': ['18:45', '18:45', '18:45', '18:45', '18:45', '18:45', '18:45', '18:45', '21:00', '21:00', '21:00', '21:00', '21:00', '21:00', '21:00', '21:00']}}

# %%
import pandas as pd
# Convert dictionary to a list of rows
data = []
for championship, details in all_matches.items():
    for teamA, teamB, result in zip(details['teamsA'], details['teamsB'], details['result']):
        data.append([championship, teamA, teamB, result])

# Create a DataFrame
df = pd.DataFrame(data, columns=['Championship', 'Team A', 'Team B', 'Result'])

# Save to a CSV file
# df.to_csv('all_matches.csv', index=False)

# Print DataFrame for tabular display
print(df.head())
# Out:
#       Championship         Team A          Team B Result
# 0  الدوري الأوروبي  كاراباج اجدام     أوليمبياكوس    0-0
# 1  الدوري الأوروبي     سان جيلواز  سبورتينج براجا    3-3
# 2  الدوري الأوروبي    آيك لارانكا         فنربخشة    1-2
# 3  الدوري الأوروبي     ريال بيتيس            روما    1-1
# 4  الدوري الأوروبي          جليمت          أرسنال    0-1

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import calendar

def get_yearly_data(year):
    all_matches = {}

    for month in range(1, 13):  # Loop through all months (1 to 12)
        num_days = calendar.monthrange(year, month)[1]

        for day in range(1, num_days + 1):
            date_str = f"{month:02d}/{day:02d}/{year}"
            try:
                url = f"https://www.yallakora.com/match-center/?date={month}/{day}/{year}"
                page = requests.get(url)
                soup = BeautifulSoup(page.content, 'lxml')

                # Check for multiple match sections
                match_sections = soup.find_all('div', {'class': 'matchCard'})
                if not match_sections:
                    print(f"No matches found for {date_str}")
                    continue

                for match in match_sections:
                    if match is None:
                        continue

                    title = match.find('h2').text.strip()  # Get the title for this championship
                    if title not in all_matches:  # Check if the title exists in the dictionary
                        all_matches[title] = {'teamsA': [], 'teamsB': [], 'result': [], 'time': [], 'date': []}

                    teams_data = match.find_all('div', {'class': 'teamsData'})
                    if not teams_data:
                        print(f"No team data found for championship: {title}")
                        continue

                    for data in teams_data:
                        teamA = data.find('div', {'class': 'teams teamA'}).text.strip()
                        teamB = data.find('div', {'class': 'teams teamB'}).text.strip()

                        if "برشلونة" not in (teamA, teamB):
                            continue

                        result_elem = data.find('div', {'class': 'MResult'})
                        result = "N/A"
                        time = "N/A"
                        if result_elem:
                            all_results = result_elem.find_all('span', {'class': 'score'})
                            if len(all_results) == 2:
                                result = f"{all_results[0].text.strip()}-{all_results[1].text.strip()}"
                            time_elem = result_elem.find('span', {'class': 'time'})
                            time = time_elem.text.strip() if time_elem else "N/A"

                        all_matches[title]['teamsA'].append(teamA)
                        all_matches[title]['teamsB'].append(teamB)
                        all_matches[title]['result'].append(result)
                        all_matches[title]['time'].append(time)
                        all_matches[title]['date'].append(date_str)

            except Exception as e:
                print(f"Error on {date_str}: {e}")

    data = []
    for championship, details in all_matches.items():
        for date, teamA, teamB, result, time in zip(details['date'], details['teamsA'], details['teamsB'], details['result'], details['time']):
            data.append([date, championship, teamA, result, teamB, time])

    df = pd.DataFrame(data, columns=['Date', 'Championship', 'Team A', 'Result', 'Team B', 'Time'])
    df.to_excel('barca_all_matches_yearlyReport.xlsx', index=False)
    print(df.head())

get_yearly_data(2023)
# Out:
# No matches found for 01/01/2023
# No matches found for 01/02/2023
# No matches found for 01/03/2023
# No matches found for 01/04/2023
# No matches found for 01/05/2023
# No matches found for 01/10/2023
# No matches found for 01/24/2023
# No matches found for 01/26/2023
# No matches found for 01/31/2023
# No matches found for 02/07/2023
# No matches found for 02/08/2023
# No matches found for 02/09/2023
# No matches found for 02/28/2023
# No matches found for 03/01/2023
# No matches found for 03/02/2023
# No matches found for 03/22/2023
# No matches found for 03/23/2023
# No matches found for 03/27/2023
# No matches found for 03/29/2023
# No matches found for 03/30/2023
# No matches found for 04/04/2023
# No matches found for 04/05/2023
# No matches found for 04/06/2023
# No matches found for 04/24/2023
# No matches found for 05/07/2023
# No matches found for 05/08/2023
# No matches found for 05/22/2023
# No matches found for 05/29/2023
# No matches found for 05/30/2023
# No matches found for 06/01/2023
# No matches found for 06/02/2023
# No matches found for 06/05/2023
# No matches found for 06/06/2023
# No matches found for 06/08/2023
# No matches found for 06/09/2023
# No matches found for 06/10/2023
# No matches found for 06/13/2023
# No matches found for 06/19/2023
# No matches found for 06/21/2023
# No matches found for 06/22/2023
# No matches found for 06/23/2023
# No matches found for 06/26/2023
# No matches found for 06/29/2023
# No matches found for 07/02/2023
# No matches found for 07/03/2023
# No matches found for 07/05/2023
# No matches found for 07/06/2023
# No matches found for 07/09/2023
# No matches found for 07/10/2023
# No matches found for 07/11/2023
# No matches found for 07/14/2023
# No matches found for 07/15/2023
# No matches found for 07/16/2023
# No matches found for 07/22/2023
# No matches found for 07/29/2023
# No matches found for 08/10/2023
# No matches found for 08/14/2023
# No matches found for 08/15/2023
# No matches found for 08/21/2023
# No matches found for 08/24/2023
# No matches found for 08/28/2023
# No matches found for 09/04/2023
# No matches found for 09/05/2023
# No matches found for 09/06/2023
# No matches found for 09/10/2023
# No matches found for 09/14/2023
# No matches found for 10/19/2023
# No matches found for 10/26/2023
# No matches found for 11/09/2023
# No matches found for 12/11/2023
# No matches found for 12/22/2023
# No matches found for 12/31/2023
#          Date     Championship         Team A Result   Team B   Time
# 0  01/08/2023  الدوري الإسباني  اتلتيكو مدريد    0-1  برشلونة  22:00
# 1  01/22/2023  الدوري الإسباني        برشلونة    1-0   خيتافي  19:30
# 2  01/28/2023  الدوري الإسباني         جيرونا    0-1  برشلونة  17:15
# 3  02/01/2023  الدوري الإسباني     ريال بيتيس    1-2  برشلونة  22:00
# 4  02/05/2023  الدوري الإسباني        برشلونة    3-0  اشبيلية  22:00

# %% [markdown]
# ### **get all titles in all pages**

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from itertools import zip_longest

ll = []

for j in range(84):
    page_number = j # i will use it to navigate between pages
    page = requests.get(f'https://wuzzuf.net/search/jobs/?a=hpb%7Cspbg&q=data%20analysis&start={page_number}')

    src = page.content # get page contents
    soup = BeautifulSoup(src, 'lxml')   # using the parser

    xx = soup.find_all('h2', {'class': 'css-m604qf'})
# print(xx)

    for i in xx:
      ll.append(i.text.strip())
    print(f"page {page_number} done")



print(ll)
# Out:
# ['Commercial Data Analyst', 'Data Analyst', 'Senior Data Analyst', 'Data Analyst', 'Senior Data Analyst', 'Data Engineer', 'Senior Data Engineer', 'Data Analyst', 'Data Analyst', 'Data Analyst', 'Data Analyst', 'Centro Data Program', 'Data Analyst', 'Software Business Analyst', 'Automotive Market Research Specialist', 'Sales & Marketing Executive', 'Research And Development Engineer', 'Digital Marketing Specialist', 'External Audit Supervisor', 'Commodity Analyst', 'Senior Performance marketing specialist', 'IT Specialist', 'Accounting Manager', 'Senior External Auditor', 'Financial Analyst', 'Purchasing Specialist', 'Junior Accountant - Payable', 'Data Analyst Team Leader', 'inventory control accountant', 'Finance Manager', 'BI Analyst', 'Retail Supervisor- Fashion Egypt', 'Process & Information Senior Officer', 'Call Center Agent', 'English call center is hiring (Graduates Only).', 'Senior Accountant', 'accounting', 'Business Data Analyst', 'Big Data Consultant', 'Financial Analysis Manager (Home Appliances)', 'Financial Planning And Analysis', 'Accounting Manager', 'Senior AR accountant', 'Logistics Executive', 'Accounting Clerk', 'MIS & Planning Analyst', 'Back Office Agent', 'Business Analyst', 'Data/Business Analyst Intern', 'English call center job (Graduates Only).', 'Senior Power BI Developer', 'Projects Specialist', 'Financial Data Analyst', 'Quality Assurance Manager', 'English call center (Graduates Only).', 'Real Estate Manager', 'Business Analyst Manager', 'Contact Center Manager', 'Senior Technical Offer and Quotation Officer', 'Digital Marketing Manager', 'English call center in Egypt (Graduates Only).', 'Data Analytics Engineer', 'Planning Specialist', 'Data Analyst', 'Data Analyst - Intern (Remote Internship - Data Analysis)', 'BI & Data Analytics Consultant', 'Data Analyst', 'Data Analyst', 'Data Analyst', 'Chief Accountant / Accounting Manager', 'Data Entry Clerk', 'Data Analyst', 'Data Analyst', 'Data Engineer Expert (ETL Informatica Tools)', 'Hiring for an English call center in Cairo- Alex (Graduates Only).', 'Accountant', 'Chief Financial Officer', 'Sr. Quality Control Specialist', 'Procurement Engineer', 'Hiring for an English call center All over Egypt (Graduates Only).', 'Senior Sales Executive', 'Accounting Manager', 'Chief Financial Officer CFO', 'Senior Data Integration Engineer', 'Accountant', 'Business Analysis Supervisor', 'Hiring English Speakers agents All over Egypt (Graduates Only).', 'Virtual Data Entry Admin Assistants – Full Time', 'Data Entry/Admin Support - Work From Home', 'Junior Level Data Entry - Work From Home', 'Data Analyst', 'Data Scientist', 'Data Analyst (0 Experience Required)', 'Work From Home Data Entry Clerk (Part/Full Time)', 'Online Data Entry Operator Needed', 'Entry-Level Work-From-Home Data Entry Jobs', 'Entry-Level Work-From-Home Data Entry Jobs', 'Online Data Entry Operator Needed', 'Part-Time/Full-Time Remote Work For Data Entry', 'Junior Data Scientist (Remote)', 'Data Entry/Admin Support - Work From Home', 'Python Data Scientist (Quantitative Finance)', 'Data Input Specialist - Healthcare Information Systems', 'Online Data Entry Operator Needed', 'Hiring English Speakers All over Egypt (Graduates Only).', 'Data Analyst - Abu Dhabi', 'Data Insights Analytics Specialist', 'CID Data Entry Agent', 'Part/Full-Time Remote Data Entry Clerk Position', 'BI Consultant', 'Immediate Need (Data Entry Operator - Remote Work)', 'Data Analyst/Market Researcher', 'HR Analyst', 'Online Data Entry Operator Needed', 'Senior Data Science Analyst', 'Full-Time Remote Data Entry Assistant', 'Data Input Specialist - Healthcare Information Systems', 'Work-From-Home Data Entry Positions', 'Senior Sales Eexcutive', 'Data Engineer', 'Senior Manager, Data Scientist', 'Financial Planning And Analysis Manager', 'Data & BI Senior Specialist', 'Data Analyst/Market Researcher', 'Remote Data Entry Administrator (Work From Home)', 'Remote Data Entry Role (Part Time)', 'Data Analyst', 'Full-Time Rem ...

# %% [markdown]
# ..

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
# from itertools import zip_longest

ll = []
titles = []
company = []
locations = []
skills = []
links = []
salaries = []

page_number = 0 # i will use it to navigate between pages
page = requests.get(f'https://wuzzuf.net/search/jobs/?a=hpb%7Cspbg&q=data%20analysis&start={page_number}')

src = page.content # get page contents
soup = BeautifulSoup(src, 'lxml')   # using the parser

job_titles = soup.find_all('h2', {'class': 'css-m604qf'})
job_company = soup.find_all('a', {'class': 'css-17s97q8'})
job_location = soup.find_all('span', {'class': 'css-5wys0k'})
job_exp = soup.find_all('div', {'class': 'css-y4udm8'}) # will need more digging
# xx = job_exp

for i in range(len(job_titles)):
    titles.append(job_titles[i].text.strip())
    links.append(job_titles[i].find('a')['href'])
    company.append(job_company[i].text.strip())
    locations.append(job_location[i].text.strip())
    skills.append(job_exp[i].text.strip())

for link in links:
    page = requests.get(link)
    src = page.content
    soup = BeautifulSoup(src, 'lxml')
    salaries.append((soup.find('span', {'class': 'css-4xky9y'})).text.strip())



# print(ll)


data = []

for i in range(len(titles)):
    data.append([titles[i], company[i], locations[i], skills[i], links[i], salaries[i]])

df = pd.DataFrame(data, columns=['Title', 'Company', 'Location', 'Skills required', 'Links', 'Salary'])

df.to_excel('Data Science WUZZUF Page-1.xlsx', index=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-4df27859d561> in <cell line: 33>()
#      35     src = page.content
#      36     soup = BeautifulSoup(src, 'lxml')
# ---> 37     salaries.append((soup.find('span', {'class': 'css-4xky9y'})).text.strip())
#      38
#      39
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
# from itertools import zip_longest

ll = []
titles = []
company = []
locations = []
skills = []
links = []
salaries = []

page_number = 0 # i will use it to navigate between pages
page = requests.get(f'https://wuzzuf.net/search/jobs/?a=hpb%7Cspbg&q=data%20analysis&start={page_number}')

src = page.content # get page contents
soup = BeautifulSoup(src, 'lxml')   # using the parser

job_titles = soup.find_all('h2', {'class': 'css-m604qf'})
job_company = soup.find_all('a', {'class': 'css-17s97q8'})
job_location = soup.find_all('span', {'class': 'css-5wys0k'})
job_exp = soup.find_all('div', {'class': 'css-y4udm8'}) # will need more digging
# xx = job_exp

for i in range(len(job_titles)):
    titles.append(job_titles[i].text.strip())
    links.append(job_titles[i].find('a')['href'])
    company.append(job_company[i].text.strip())
    locations.append(job_location[i].text.strip())
    skills.append(job_exp[i].text.strip())

for link in links:
    page = requests.get(link)
    src = page.content
    soup = BeautifulSoup(src, 'lxml')
    salary_element = soup.find('span', {'class': 'css-4xky9y'}) # find the salary element
    if salary_element: # check if salary element exists
        salaries.append(salary_element.text.strip())
    else:
        salaries.append('N/A') # append N/A if salary info is not found


# print(ll)


data = []

for i in range(len(titles)):
    data.append([titles[i], company[i], locations[i], skills[i], links[i], salaries[i]])

df = pd.DataFrame(data, columns=['Title', 'Company', 'Location', 'Skills required', 'Links', 'Salary'])

df.to_excel('Data Science WUZZUF Page-1.xlsx', index=False)
