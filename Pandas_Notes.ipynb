# %% [markdown]
# # **Pandas**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as plt

# %%
pd.set_option('display.max_columns', None)
df = pd.read_csv('https://raw.githubusercontent.com/omarEssam-11/Data-Science/main/world_population.csv')
df
# Out:
#      Rank CCA3            Country           Capital Continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara          El Aaiún    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 232    63  ZMB             Zambia            Lusaka    Africa
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0         41128771.0       38972230.0       33753499.0       28189672.0
# 1          2842321.0        2866849.0        2882481.0        2913399.0
# ...

# %% [markdown]
# ## **Filtering & Ordering**

# %% [markdown]
# ## **Filtering**

# %%
df[df['Rank'] > 10]
# Out:
#      Rank CCA3            Country           Capital Continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara          El Aaiún    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 232    63  ZMB             Zambia            Lusaka    Africa
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0         41128771.0       38972230.0       33753499.0       28189672.0
# 1          2842321.0        2866849.0        2882481.0        2913399.0
# ...

# %%
df[df['Continent'] == 'Africa']
# Out:
#      Rank CCA3                   Country       Capital Continent  \
# 2      34  DZA                   Algeria       Algiers    Africa
# 5      42  AGO                    Angola        Luanda    Africa
# 21     77  BEN                     Benin    Porto-Novo    Africa
# 26    144  BWA                  Botswana      Gaborone    Africa
# 31     58  BFA              Burkina Faso   Ouagadougou    Africa
# 32     78  BDI                   Burundi     Bujumbura    Africa
# 34     53  CMR                  Cameroon       Yaounde    Africa
# 36    171  CPV                Cape Verde         Praia    Africa
# 38    117  CAF  Central African Republic        Bangui    Africa
# 39     69  TCD                      Chad     N'Djamena    Africa
# 43    163  COM                   Comoros        Moroni    Africa
# 52    160  DJI                  Djibouti      Djibouti    Africa
# 55     15  COD                  DR Congo      Kinshasa    Africa
# ...

# %%
df[(df['Continent'] == 'Asia') & (df['Rank'] <= 15)]
# Out:
#      Rank CCA3      Country    Capital Continent  2022 Population  \
# 16      8  BGD   Bangladesh      Dhaka      Asia     1.711864e+08
# 41      1  CHN        China    Beijing      Asia     1.425887e+09
# 92      2  IND        India  New Delhi      Asia     1.417173e+09
# 93      4  IDN    Indonesia    Jakarta      Asia     2.755013e+08
# 102    11  JPN        Japan      Tokyo      Asia     1.239517e+08
# 156     5  PAK     Pakistan  Islamabad      Asia     2.358249e+08
# 163    13  PHL  Philippines     Manila      Asia     1.155590e+08
#
#      2020 Population  2015 Population  2010 Population  2000 Population  \
# 16      1.674210e+08     1.578300e+08     1.483911e+08     1.291933e+08
# 41      1.424930e+09     1.393715e+09     1.348191e+09     1.264099e+09
# 92      1.396387e+09     1.322867e+09     1.240614e+09     1.059634e+09
# 93      2.718580e+08     2.590920e+08     2.440162e+08     2.140724e+08
# 102     1.252448e+08     1.272509e+08     1.281054e+08     1.268039e+08
# ...

# %%
df[df['Country'].isin (['Egypt', 'Algeria', 'Tunisia'])]
# df
# Out:
#      Rank CCA3  Country  Capital Continent  2022 Population  2020 Population  \
# 2      34  DZA  Algeria  Algiers    Africa       44903225.0       43451666.0
# 57     14  EGY    Egypt    Cairo    Africa      110990103.0      107465134.0
# 212    79  TUN  Tunisia    Tunis    Africa       12356117.0       12161723.0
#
#      2015 Population  2010 Population  2000 Population  1990 Population  \
# 2         39543154.0       35856344.0       30774621.0       25518074.0
# 57        97723799.0       87252413.0       71371371.0       57214630.0
# 212       11557779.0       10895063.0        9893316.0        8440023.0
#
#      1980 Population  1970 Population  Area (km²)  Density (per km²)  \
# 2         18739378.0       13795915.0   2381741.0            18.8531
# 57        43748556.0       34781986.0   1002450.0           110.7188
# 212        6578156.0        5047404.0    163610.0            75.5218
#
#      Growth Rate  World Population Percentage
# ...

# %%
# .str.contains similiar to like in sql
df[df['Country'].str.contains('United')]
# Out:
#      Rank CCA3                       Country           Capital      Continent  \
# 219    97  ARE          United Arab Emirates         Abu Dhabi           Asia
# 220    21  GBR                United Kingdom            London         Europe
# 221     3  USA                 United States  Washington, D.C.  North America
# 222   200  VIR  United States Virgin Islands  Charlotte Amalie  North America
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 219        9441129.0        9287289.0        8916899.0        8481771.0
# 220       67508936.0       67059474.0       65224364.0       62760039.0
# 221      338289857.0      335942003.0      324607776.0      311182845.0
# 222          99465.0         100442.0         102803.0         106142.0
#
#      2000 Population  1990 Population  1980 Population  1970 Population  \
# 219        3275333.0        1900151.0        1014048.0         298084.0
# ...

# %%
df2 = df.set_index('Country')
df2
# Out:
#                    Rank CCA3           Capital Continent  2022 Population  \
# Country
# Afghanistan          36  AFG             Kabul      Asia       41128771.0
# Albania             138  ALB            Tirana    Europe        2842321.0
# Algeria              34  DZA           Algiers    Africa       44903225.0
# American Samoa      213  ASM         Pago Pago   Oceania          44273.0
# Andorra             203  AND  Andorra la Vella    Europe          79824.0
# ...                 ...  ...               ...       ...              ...
# Wallis and Futuna   226  WLF          Mata-Utu   Oceania          11572.0
# Western Sahara      172  ESH          El Aaiún    Africa         575986.0
# Yemen                46  YEM             Sanaa      Asia       33696614.0
# Zambia               63  ZMB            Lusaka    Africa       20017675.0
# Zimbabwe             74  ZWE            Harare    Africa       16320537.0
#
# ...

# %%
df2.filter(items=['Capital', 'CCA3'])
# Out:
#                             Capital CCA3
# Country
# Afghanistan                   Kabul  AFG
# Albania                      Tirana  ALB
# Algeria                     Algiers  DZA
# American Samoa            Pago Pago  ASM
# Andorra            Andorra la Vella  AND
# ...                             ...  ...
# Wallis and Futuna          Mata-Utu  WLF
# Western Sahara             El Aaiún  ESH
# Yemen                         Sanaa  YEM
# Zambia                       Lusaka  ZMB
# Zimbabwe                     Harare  ZWE
#
# [234 rows x 2 columns]

# %%
df2.filter(like='Alger', axis=0)
# Out:
#          Rank CCA3  Capital Continent  2022 Population  2020 Population  \
# Country
# Algeria    34  DZA  Algiers    Africa       44903225.0       43451666.0
#
#          2015 Population  2010 Population  2000 Population  1990 Population  \
# Country
# Algeria       39543154.0       35856344.0       30774621.0       25518074.0
#
#          1980 Population  1970 Population  Area (km²)  Density (per km²)  \
# Country
# Algeria       18739378.0       13795915.0   2381741.0            18.8531
#
#          Growth Rate  World Population Percentage
# Country
# Algeria       1.0164                         0.56

# %%
df2.loc['Egypt']
# Out:
# Rank                                    14
# CCA3                                   EGY
# Capital                              Cairo
# Continent                           Africa
# 2022 Population                110990103.0
# 2020 Population                107465134.0
# 2015 Population                 97723799.0
# 2010 Population                 87252413.0
# 2000 Population                 71371371.0
# 1990 Population                 57214630.0
# 1980 Population                 43748556.0
# 1970 Population                 34781986.0
# Area (km²)                       1002450.0
# Density (per km²)                 110.7188
# Growth Rate                         1.0158
# World Population Percentage           1.39
# Name: Egypt, dtype: object

# %%
df2.iloc[7]
# Out:
# Rank                                     201
# CCA3                                     ATG
# Capital                         Saint John’s
# Continent                      North America
# 2022 Population                      93763.0
# 2020 Population                      92664.0
# 2015 Population                      89941.0
# 2010 Population                      85695.0
# 2000 Population                      75055.0
# 1990 Population                      63328.0
# 1980 Population                      64888.0
# 1970 Population                      64516.0
# Area (km²)                             442.0
# Density (per km²)                   212.1335
# Growth Rate                           1.0058
# World Population Percentage              0.0
# Name: Antigua and Barbuda, dtype: object

# %% [markdown]
# ## Ordering

# %%
df.sort_values(by='Rank')
# Out:
#      Rank CCA3           Country           Capital      Continent  \
# 41      1  CHN             China           Beijing           Asia
# 92      2  IND             India         New Delhi           Asia
# 221     3  USA     United States  Washington, D.C.  North America
# 93      4  IDN         Indonesia           Jakarta           Asia
# 156     5  PAK          Pakistan         Islamabad           Asia
# ..    ...  ...               ...               ...            ...
# 137   230  MSR        Montserrat            Brades  North America
# 64    231  FLK  Falkland Islands           Stanley  South America
# 150   232  NIU              Niue             Alofi        Oceania
# 209   233  TKL           Tokelau          Nukunonu        Oceania
# 226   234  VAT      Vatican City      Vatican City         Europe
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 41      1.425887e+09     1.424930e+09     1.393715e+09     1.348191e+09
# ...

# %%
df.sort_values(by=['Continent', 'Country'])
# Out:
#      Rank CCA3       Country      Capital      Continent  2022 Population  \
# 2      34  DZA       Algeria      Algiers         Africa       44903225.0
# 5      42  AGO        Angola       Luanda         Africa       35588987.0
# 21     77  BEN         Benin   Porto-Novo         Africa       13352864.0
# 26    144  BWA      Botswana     Gaborone         Africa        2630296.0
# 31     58  BFA  Burkina Faso  Ouagadougou         Africa       22673762.0
# ..    ...  ...           ...          ...            ...              ...
# 161   109  PRY      Paraguay     Asunción  South America        6780744.0
# 162    44  PER          Peru         Lima  South America       34049588.0
# 199   170  SUR      Suriname   Paramaribo  South America         618040.0
# 223   133  URY       Uruguay   Montevideo  South America        3422794.0
# 227    51  VEN     Venezuela      Caracas  South America       28301696.0
#
#      2020 Population  2015 Population  2010 Population  2000 Population  \
# ...

# %%
df.sort_values(by=['Continent', 'Country'], ascending=False)
# Out:
#      Rank CCA3       Country      Capital      Continent  2022 Population  \
# 227    51  VEN     Venezuela      Caracas  South America       28301696.0
# 223   133  URY       Uruguay   Montevideo  South America        3422794.0
# 199   170  SUR      Suriname   Paramaribo  South America         618040.0
# 162    44  PER          Peru         Lima  South America       34049588.0
# 161   109  PRY      Paraguay     Asunción  South America        6780744.0
# ..    ...  ...           ...          ...            ...              ...
# 31     58  BFA  Burkina Faso  Ouagadougou         Africa       22673762.0
# 26    144  BWA      Botswana     Gaborone         Africa        2630296.0
# 21     77  BEN         Benin   Porto-Novo         Africa       13352864.0
# 5      42  AGO        Angola       Luanda         Africa       35588987.0
# 2      34  DZA       Algeria      Algiers         Africa       44903225.0
#
#      2020 Population  2015 Population  2010 Population  2000 Population  \
# ...

# %%
df[(df['Rank'] < 25) & (df['Continent'] == 'Africa')].sort_values(by=['Rank'])
# Out:
#      Rank CCA3       Country      Capital Continent  2022 Population  \
# 149     6  NGA       Nigeria        Abuja    Africa      218541212.0
# 63     12  ETH      Ethiopia  Addis Ababa    Africa      123379924.0
# 57     14  EGY         Egypt        Cairo    Africa      110990103.0
# 55     15  COD      DR Congo     Kinshasa    Africa       99010212.0
# 205    22  TZA      Tanzania       Dodoma    Africa       65497748.0
# 193    24  ZAF  South Africa     Pretoria    Africa       59893885.0
#
#      2020 Population  2015 Population  2010 Population  2000 Population  \
# 149      208327405.0      183995785.0      160952853.0      122851984.0
# 63       117190911.0      102471895.0       89237791.0       67031867.0
# 57       107465134.0       97723799.0       87252413.0       71371371.0
# 55        92853164.0       78656904.0       66391257.0       48616317.0
# 205       61704518.0       52542823.0       45110527.0       34463704.0
# ...

# %% [markdown]
# ## **Indexing**

# %%
#1
df2 = pd.read_csv('https://raw.githubusercontent.com/omarEssam-11/Data-Science/main/world_population.csv', index_col='Country')
df2
# Out:
#                    Rank CCA3           Capital Continent  2022 Population  \
# Country
# Afghanistan          36  AFG             Kabul      Asia       41128771.0
# Albania             138  ALB            Tirana    Europe        2842321.0
# Algeria              34  DZA           Algiers    Africa       44903225.0
# American Samoa      213  ASM         Pago Pago   Oceania          44273.0
# Andorra             203  AND  Andorra la Vella    Europe          79824.0
# ...                 ...  ...               ...       ...              ...
# Wallis and Futuna   226  WLF          Mata-Utu   Oceania          11572.0
# Western Sahara      172  ESH          El Aaiún    Africa         575986.0
# Yemen                46  YEM             Sanaa      Asia       33696614.0
# Zambia               63  ZMB            Lusaka    Africa       20017675.0
# Zimbabwe             74  ZWE            Harare    Africa       16320537.0
#
# ...

# %%
# to reset index
df2.reset_index(inplace=True)
df2
# Out:
#                Country  Rank CCA3           Capital Continent  \
# 0          Afghanistan    36  AFG             Kabul      Asia
# 1              Albania   138  ALB            Tirana    Europe
# 2              Algeria    34  DZA           Algiers    Africa
# 3       American Samoa   213  ASM         Pago Pago   Oceania
# 4              Andorra   203  AND  Andorra la Vella    Europe
# ..                 ...   ...  ...               ...       ...
# 229  Wallis and Futuna   226  WLF          Mata-Utu   Oceania
# 230     Western Sahara   172  ESH          El Aaiún    Africa
# 231              Yemen    46  YEM             Sanaa      Asia
# 232             Zambia    63  ZMB            Lusaka    Africa
# 233           Zimbabwe    74  ZWE            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0         41128771.0       38972230.0       33753499.0       28189672.0
# 1          2842321.0        2866849.0        2882481.0        2913399.0
# ...

# %%
#2

df2.set_index('Country', inplace=True)
df2.head()
# Out:
#                 Rank CCA3           Capital Continent  2022 Population  \
# Country
# Afghanistan       36  AFG             Kabul      Asia       41128771.0
# Albania          138  ALB            Tirana    Europe        2842321.0
# Algeria           34  DZA           Algiers    Africa       44903225.0
# American Samoa   213  ASM         Pago Pago   Oceania          44273.0
# Andorra          203  AND  Andorra la Vella    Europe          79824.0
#
#                 2020 Population  2015 Population  2010 Population  \
# Country
# Afghanistan          38972230.0       33753499.0       28189672.0
# Albania               2866849.0        2882481.0        2913399.0
# Algeria              43451666.0       39543154.0       35856344.0
# American Samoa          46189.0          51368.0          54849.0
# Andorra                 77700.0          71746.0          71519.0
#
#                 2000 Population  1990 Population  1980 Population  \
# Country
# ...

# %%
# df2.reset_index(inplace=True)
# df2.head()

# %%
# loc and iloc


df2.loc['Algeria']    # label
# Out:
# Rank                                   34
# CCA3                                  DZA
# Capital                           Algiers
# Continent                          Africa
# 2022 Population                44903225.0
# 2020 Population                43451666.0
# 2015 Population                39543154.0
# 2010 Population                35856344.0
# 2000 Population                30774621.0
# 1990 Population                25518074.0
# 1980 Population                18739378.0
# 1970 Population                13795915.0
# Area (km²)                      2381741.0
# Density (per km²)                 18.8531
# Growth Rate                        1.0164
# World Population Percentage          0.56
# Name: Algeria, dtype: object

# %%
df2.iloc[2]  #int location
# Out:
# Rank                                   34
# CCA3                                  DZA
# Capital                           Algiers
# Continent                          Africa
# 2022 Population                44903225.0
# 2020 Population                43451666.0
# 2015 Population                39543154.0
# 2010 Population                35856344.0
# 2000 Population                30774621.0
# 1990 Population                25518074.0
# 1980 Population                18739378.0
# 1970 Population                13795915.0
# Area (km²)                      2381741.0
# Density (per km²)                 18.8531
# Growth Rate                        1.0164
# World Population Percentage          0.56
# Name: Algeria, dtype: object

# %% [markdown]
# ### Multi index

# %%
df2.reset_index(inplace=True)


df2.set_index(['Continent', 'Country'], inplace=True)
df2.head()
# Out:
#                           Rank CCA3           Capital  2022 Population  \
# Continent Country
# Asia      Afghanistan       36  AFG             Kabul       41128771.0
# Europe    Albania          138  ALB            Tirana        2842321.0
# Africa    Algeria           34  DZA           Algiers       44903225.0
# Oceania   American Samoa   213  ASM         Pago Pago          44273.0
# Europe    Andorra          203  AND  Andorra la Vella          79824.0
#
#                           2020 Population  2015 Population  2010 Population  \
# Continent Country
# Asia      Afghanistan          38972230.0       33753499.0       28189672.0
# Europe    Albania               2866849.0        2882481.0        2913399.0
# Africa    Algeria              43451666.0       39543154.0       35856344.0
# Oceania   American Samoa          46189.0          51368.0          54849.0
# Europe    Andorra                 77700.0          71746.0          71519.0
#
# ...

# %%
df2.sort_index(inplace=True, ascending=True)
df2
# Out:
#                             Rank CCA3      Capital  2022 Population  \
# Continent     Country
# Africa        Algeria         34  DZA      Algiers       44903225.0
#               Angola          42  AGO       Luanda       35588987.0
#               Benin           77  BEN   Porto-Novo       13352864.0
#               Botswana       144  BWA     Gaborone        2630296.0
#               Burkina Faso    58  BFA  Ouagadougou       22673762.0
# ...                          ...  ...          ...              ...
# South America Paraguay       109  PRY     Asunción        6780744.0
#               Peru            44  PER         Lima       34049588.0
#               Suriname       170  SUR   Paramaribo         618040.0
#               Uruguay        133  URY   Montevideo        3422794.0
#               Venezuela       51  VEN      Caracas       28301696.0
#
#                             2020 Population  2015 Population  2010 Population  \
# Continent     Country
# ...

# %%
df2.loc['Africa']
# Out:
#                           Rank CCA3       Capital  2022 Population  \
# Country
# Algeria                     34  DZA       Algiers       44903225.0
# Angola                      42  AGO        Luanda       35588987.0
# Benin                       77  BEN    Porto-Novo       13352864.0
# Botswana                   144  BWA      Gaborone        2630296.0
# Burkina Faso                58  BFA   Ouagadougou       22673762.0
# Burundi                     78  BDI     Bujumbura       12889576.0
# Cameroon                    53  CMR       Yaounde       27914536.0
# Cape Verde                 171  CPV         Praia         593149.0
# Central African Republic   117  CAF        Bangui        5579144.0
# Chad                        69  TCD     N'Djamena       17723315.0
# Comoros                    163  COM        Moroni         836774.0
# DR Congo                    15  COD      Kinshasa       99010212.0
# Djibouti                   160  DJI      Djibouti        1120849.0
# ...

# %%
df2.loc['Africa', 'Egypt']
# Out:
# Rank                                    14
# CCA3                                   EGY
# Capital                              Cairo
# 2022 Population                110990103.0
# 2020 Population                107465134.0
# 2015 Population                 97723799.0
# 2010 Population                 87252413.0
# 2000 Population                 71371371.0
# 1990 Population                 57214630.0
# 1980 Population                 43748556.0
# 1970 Population                 34781986.0
# Area (km²)                       1002450.0
# Density (per km²)                 110.7188
# Growth Rate                         1.0158
# World Population Percentage           1.39
# Name: (Africa, Egypt), dtype: object

# %% [markdown]
# ## Group By and Aggregate Functions

# %%
dff = pd.read_csv('https://raw.githubusercontent.com/amrutakulkarni9812/Stack-Overflow-Developer-Survey-Analysis/master/survey-results-public.csv')
dff.head()
# Out:
#    Respondent                                       Professional  \
# 0           1                                            Student
# 1           2                                            Student
# 2           3                             Professional developer
# 3           4  Professional non-developer who sometimes write...
# 4           5                             Professional developer
#
#                 ProgramHobby         Country      University  \
# 0                  Yes, both   United States              No
# 1                  Yes, both  United Kingdom  Yes, full-time
# 2                  Yes, both  United Kingdom              No
# 3                  Yes, both   United States              No
# 4  Yes, I program as a hobby     Switzerland              No
#
#                          EmploymentStatus  \
# 0  Not employed, and not looking for work
# 1                      Employed part-time
# 2                      Employed full-time
# ...

# %%
dff.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51392 entries, 0 to 51391
# Columns: 154 entries, Respondent to ExpectedSalary
# dtypes: float64(6), int64(1), object(147)
# memory usage: 60.4+ MB

# %%
dff.describe()
# Out:
#          Respondent  CareerSatisfaction  JobSatisfaction  HoursPerWeek  \
# count  51392.000000        42695.000000     40376.000000  20600.000000
# mean   25696.500000            7.300574         6.957078      3.952282
# std    14835.736854            1.955444         2.167652      7.564722
# min        1.000000            0.000000         0.000000      0.000000
# 25%    12848.750000            6.000000         6.000000      1.000000
# 50%    25696.500000            8.000000         7.000000      1.000000
# 75%    38544.250000            9.000000         8.000000      4.000000
# max    51392.000000           10.000000        10.000000     40.000000
#
#        StackOverflowSatisfaction         Salary  ExpectedSalary
# count               36592.000000   12891.000000     2566.000000
# mean                    8.429875   56298.480641    33142.220468
# std                     1.390635   39880.905277    30162.988829
# min                     0.000000       0.000000        0.000000
# ...

# %%
#dff['Salary'].median()
#dff['Salary'].mean()

# %%
dff['VersionControl'].value_counts()
# Out:
# VersionControl
# Git                                            21266
# Subversion                                      2790
# Team Foundation Server                          2255
# I don't use version control                     1468
# I use some other system                          924
# Zip file back-ups                                609
# Mercurial                                        591
# Copying and pasting files to network shares      510
# Visual Source Safe                               196
# Rational ClearCase                               121
# Name: count, dtype: int64

# %%
dff['Gender'].value_counts()
# Out:
# Gender
# Male                                                       31589
# Female                                                      2600
# Other                                                        225
# Male; Other                                                  171
# Gender non-conforming                                        160
# Male; Gender non-conforming                                   65
# Female; Transgender                                           56
# Transgender                                                   55
# Female; Gender non-conforming                                 29
# Male; Female                                                  15
# Transgender; Gender non-conforming                            15
# Male; Female; Transgender; Gender non-conforming; Other       15
# Male; Transgender                                             11
# Female; Transgender; Gender non-conforming                     8
# ...

# %%
xx = dff['IDE'].value_counts()
xx[xx > 1000]
# Out:
# IDE
# Notepad++; Visual Studio    1624
# Visual Studio               1566
# Vim                         1217
# Name: count, dtype: int64

# %%
zz = dff['HaveWorkedLanguage'].value_counts()
zz[(zz.index.str.contains('Python'))]
# Out:
# HaveWorkedLanguage
# Python                                                                                                              529
# JavaScript; Python                                                                                                  384
# JavaScript; PHP; Python; SQL                                                                                        253
# Java; Python                                                                                                        207
# JavaScript; Python; SQL                                                                                             203
#                                                                                                                    ...
# Assembly; C; Java; JavaScript; Python; SQL; TypeScript                                                                1
# C; C++; CoffeeScript; Common Lisp; Go; Haskell; Java; JavaScript; Perl; PHP; Python; R; Ruby; SQL; Swift; VB.NET      1
# ...

# %%
zz[(zz.index.str.contains('Python'))].sum()
# Out:
# 11704

# %% [markdown]
# **Group by =>  [split]  => [applay Function]  => [combine results]**

# %%
country_grp = dff.groupby('Country')

# %%
country_grp.get_group('Egypt').head(5)
# Out:
#       Respondent            Professional               ProgramHobby Country  \
# 587          588  Professional developer  Yes, I program as a hobby   Egypt
# 1140        1141                 Student                  Yes, both   Egypt
# 1367        1368                 Student  Yes, I program as a hobby   Egypt
# 1649        1650  Professional developer  Yes, I program as a hobby   Egypt
# 1850        1851  Professional developer                  Yes, both   Egypt
#
#           University                                   EmploymentStatus  \
# 587   Yes, full-time                 Not employed, but looking for work
# 1140  Yes, full-time                 Not employed, but looking for work
# 1367  Yes, full-time             Not employed, and not looking for work
# 1649  Yes, full-time  Independent contractor, freelancer, or self-em...
# 1850              No                                 Employed full-time
#
#                                         FormalEducation  \
# ...

# %%
country_grp['WantWorkLanguage'].value_counts()
# Out:
# Country      WantWorkLanguage
# Afghanistan  Assembly; C; C++; C#; F#; Groovy; JavaScript                         1
#              PHP; SQL                                                             1
#              Java; Ruby                                                           1
#              Go                                                                   1
#              F#; JavaScript; Lua; Objective-C; PHP; Rust; Swift; VB.NET           1
#                                                                                  ..
# Zimbabwe     C++; C#; Java; JavaScript; Matlab; PHP; Python; Ruby; SQL; VB.NET    1
#              C#; Java; JavaScript                                                 1
#              C#; Groovy; Java; JavaScript; SQL                                    1
#              Assembly; C++; JavaScript; Python; Ruby                              1
#              Java; JavaScript; Objective-C; PHP; SQL                              1
# ...

# %%
country_grp['WantWorkLanguage'].value_counts().loc["Egypt"]
# Out:
# WantWorkLanguage
# Python                          3
# Go; JavaScript; Python          2
# Java; JavaScript                2
# C++; Python                     2
# C; C++                          2
#                                ..
# Python; R; Scala                1
# Objective-C; Python; R; Ruby    1
# JavaScript; Python; SQL         1
# JavaScript; Python              1
# JavaScript; Matlab; PHP         1
# Name: count, Length: 68, dtype: int64

# %%
country_grp['DeveloperType'].value_counts().loc['Germany']
# Out:
# DeveloperType
# Web developer                                                                                                                   579
# Desktop applications developer                                                                                                  186
# Web developer; Desktop applications developer                                                                                   146
# Web developer; Mobile developer                                                                                                 102
# Other                                                                                                                            90
#                                                                                                                                ...
# Web developer; Mobile developer; Graphic designer; Quality assurance engineer                                                     1
# ...

# %%
z = country_grp['DeveloperType'].value_counts().loc['Germany']
z.head(1)
# Out:
# DeveloperType
# Web developer    579
# Name: count, dtype: int64

# %%
# getting most common developer type for each country and his percentage

#Note : The idxmax() function in Pandas is used to find the index of the first occurrence of the maximum value in a Series.



def get_most_common_developer(countries):
  data=[]
  for country in countries:
    most_common = (country_grp['DeveloperType'].value_counts(normalize=True).loc[country].idxmax())
    percent = (country_grp['DeveloperType'].value_counts(normalize=True).loc[country]).max() * 100
    data.append((country, most_common, percent))
  return pd.DataFrame(data, columns=['Country', 'Developer Type', 'Percentage'])



get_most_common_developer(['Egypt', 'Germany', 'India', 'United States'])
# Out:
#          Country Developer Type  Percentage
# 0          Egypt  Web developer   31.460674
# 1        Germany  Web developer   20.925190
# 2          India  Web developer   35.194881
# 3  United States  Web developer   30.428503

# %%
def get_most_common_developer_all_countries(country_grp):
    data = []
    for country, group in country_grp:

        dev_type_counts = group['DeveloperType'].value_counts()

        if dev_type_counts.empty:
          continue

        most_common = dev_type_counts.idxmax()

        devs_no = dev_type_counts.max()
        data.append([country, most_common, devs_no])

    return pd.DataFrame(data, columns=['Country', 'Most Common Developer Type', 'No. of Developers']).sort_values(by='No. of Developers', ascending=False)



get_most_common_developer_all_countries(country_grp).head(14)
# Out:
#                 Country Most Common Developer Type  No. of Developers
# 172       United States              Web developer               2528
# 75                India              Web developer               1210
# 171      United Kingdom              Web developer               1129
# 61              Germany              Web developer                579
# 35               Canada              Web developer                453
# 57               France              Web developer                337
# 128              Poland              Web developer                326
# 150               Spain              Web developer                216
# 13            Australia              Web developer                200
# 135  Russian Federation              Web developer                192
# 113         Netherlands              Web developer                172
# 134             Romania              Web developer                160
# ...

# %% [markdown]
# ## Merging & concat DataFrames

# %%
# merge VS concat

# merge like join in sql &&  concat like union

t1 = pd.read_csv('https://raw.githubusercontent.com/AlexTheAnalyst/PandasYouTubeSeries/main/LOTR.csv')
t2 = pd.read_csv('https://raw.githubusercontent.com/AlexTheAnalyst/PandasYouTubeSeries/main/LOTR%202.csv')

t1.merge(t2) # by default inner join on FellowshipID	and  FirstName
# Out:
#    FellowshipID FirstName     Skills  Age
# 0          1001     Frodo     Hiding   50
# 1          1002   Samwise  Gardening   39

# %%
t1.merge(t2, how='outer')
# Out:
#    FellowshipID FirstName     Skills     Age
# 0          1001     Frodo     Hiding    50.0
# 1          1002   Samwise  Gardening    39.0
# 2          1003   Gandalf     Spells     NaN
# 3          1004    Pippin  Fireworks     NaN
# 4          1006   Legolas        NaN  2931.0
# 5          1007    Elrond        NaN  6520.0
# 6          1008  Barromir        NaN    51.0

# %%
t1.merge(t2, on=['FellowshipID'], how='outer')
# Out:
#    FellowshipID FirstName_x     Skills FirstName_y     Age
# 0          1001       Frodo     Hiding       Frodo    50.0
# 1          1002     Samwise  Gardening     Samwise    39.0
# 2          1003     Gandalf     Spells         NaN     NaN
# 3          1004      Pippin  Fireworks         NaN     NaN
# 4          1006         NaN        NaN     Legolas  2931.0
# 5          1007         NaN        NaN      Elrond  6520.0
# 6          1008         NaN        NaN    Barromir    51.0

# %%
pd.concat([t1, t2]) # putting them on top of each other
# Out:
#    FellowshipID FirstName     Skills     Age
# 0          1001     Frodo     Hiding     NaN
# 1          1002   Samwise  Gardening     NaN
# 2          1003   Gandalf     Spells     NaN
# 3          1004    Pippin  Fireworks     NaN
# 0          1001     Frodo        NaN    50.0
# 1          1002   Samwise        NaN    39.0
# 2          1006   Legolas        NaN  2931.0
# 3          1007    Elrond        NaN  6520.0
# 4          1008  Barromir        NaN    51.0

# %% [markdown]
# ## Pandas Visualizations

# %%
aa = country_grp['DeveloperType'].value_counts().loc['Germany'].head(10)
aa.plot(kind='bar')
# Out:
# <Axes: xlabel='DeveloperType'>

# %%
#top salaries countries
qq = country_grp['Salary'].median()
qq[qq >1].sort_values(ascending=False).head(13)
# Out:
# Country
# Virgin Islands (USA)           175000.000000
# Bermuda                        150000.000000
# U.S. Minor Outlying Islands    136000.000000
# Uganda                         120000.000000
# Kuwait                         115200.000000
# Anguilla                       100000.000000
# United States                   93000.000000
# Switzerland                     90000.000000
# Iceland                         80645.161290
# Liechtenstein                   79300.000000
# Guam                            78800.000000
# Bahrain                         75000.000000
# Norway                          71770.334928
# Name: Salary, dtype: float64

# %%
qq[qq >1].sort_values(ascending=False).head(13).plot(kind='bar')
# Out:
# <Axes: xlabel='Country'>

# %%
qq[qq >1].sort_values(ascending=False).head(13).plot(kind='barh', title='Top 13 Median Salaries', xlabel='Salary', ylabel='Country')
# Out:
# <Axes: title={'center': 'Top 13 Median Salaries'}, xlabel='Salary', ylabel='Country'>

# %%
bb= qq[qq >1].sort_values(ascending=False).head(13)
bb.plot(kind='line', figsize=(20, 5))
# Out:
# <Axes: xlabel='Country'>

# %%
zz.head(15).plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
ll = df[['Country','2022 Population', '2020 Population', '2015 Population']].sort_values('2022 Population', ascending = False).head(15)
ll.set_index('Country', inplace=True)
ll.plot(kind='barh', figsize=(10, 10))
# Out:
# <Axes: ylabel='Country'>

# %%
ll.plot(kind='kde', figsize=(10, 10), subplots=True)
# Out:
# array([<Axes: ylabel='Density'>, <Axes: ylabel='Density'>,
#        <Axes: ylabel='Density'>], dtype=object)
